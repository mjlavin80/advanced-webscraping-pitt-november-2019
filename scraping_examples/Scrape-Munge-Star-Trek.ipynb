# %%
early = "https://memory-alpha.fandom.com/wiki/Starfleet_casualties_(22nd_century)"
middle = "https://memory-alpha.fandom.com/wiki/Starfleet_casualties_(23rd_century)"
late = "https://memory-alpha.fandom.com/wiki/Starfleet_casualties_(24th_century)"

all_pages = [early, middle, late]

# %%
from bs4 import BeautifulSoup
import requests, time

# %%
html = []
for i in all_pages:
    r = requests.get(i)
    html.append(r.text)
    time.sleep(2)

# %%
soups = []
for h in html: 
    soup = BeautifulSoup(h)
    soups.append(soup)

# %%
rows = []
for bs in soups:
    tables = bs.find_all("table", {"class": "grey chart"})
    for i in tables:
        heads = " ".join([j.text.lower() for j in i.find_all("th")])
        if "revival" not in heads:
            these_rows = i.find_all("tr")
            for row in these_rows:
                if len(row.find_all("td")) > 1:
                    rows.append(row)

# %%
len(rows)
# Out:
# 226

# %%
results = []
year = []
for row in rows:
    # date uses rowspan to imply repetition
    cols = row.find_all("td")
    rowlen = len(cols)
    if rowlen == 8:
        year.append(cols[0])
        cols = cols[1:]
        rowlen = len(cols)
    if rowlen == 7:
        # year is separate
        # rank, image, name, species, position, cause, reference
        try: 
            color = cols[0]['style'].split(":")[1].strip()
        except:
            color = "Unknown/Other"
        try: 
            rank = cols[0].find_all("area")[0]['title'].strip()
        except:
            rank = "Other/No Rank"
        try: 
            designation = cols[1].find_all("area")[0]['title'].strip()
        except:
            designation = "Other/No Designation"
        results.append([year[-1].text.strip(), color, cols[2].text.strip(), cols[3].text.strip(), cols[4].text.strip(), rank, designation, cols[5].text.strip(), cols[6].text.strip()])

# %%
colors = [i[1] for i in results]

# %%
from collections import Counter 
Counter(colors).most_common()
# Out:
# [('#AD722C', 59),
#  ('#A01502', 24),
#  ('transparent', 21),
#  ('#5B1414', 18),
#  ('#8C212B', 15),
#  ('#143F48', 11),
#  ('Unknown/Other', 7),
#  ('#62749A', 7),
#  ('#B59C5A', 6),
#  ('#FEFEFE', 5),
#  ('#742222', 4),
#  ('#B87333', 4),
#  ('#C0C0C0', 4),
#  ('#F79C07;', 4),
#  ('#0A0000', 4),
#  ('grey', 4),
#  ('#F6DBD0', 3),
#  ('#98925E', 3),
#  ('#B59C5A;', 3),
#  ('#FFFFFF', 2),
#  ('goldenrod;', 2),
#  ('#FEFEFE;', 2),
#  ('gold', 2),
#  ('#112959', 2),
#  ('#073835', 1),
#  ('#1A3F73', 1),
#  ('#FFFC00', 1),
#  ('#FE0100', 1),
#  ('#CC0000', 1),
#  ('#B87333;', 1),
#  ('#62749A;', 1),
#  ('#A7A0AB', 1),
#  ('blank', 1),
#  ('black', 1)]

# %%
color_groups = {'#AD722C': 'Yellow', '#A01502':'Red', '#5B1414':'Red', '#8C212B':'Red', '#143F48':'Green/Blue',
          '#62749A':'Green/Blue', '#B59C5A':'Yellow', '#FEFEFE':'White', 'transparent':'Unknown/Other', 
          'Unknown/Other':'Unknown/Other', '#742222':'Red', '#F79C07;':'Yellow', '#0A0000':'Black', 
          'grey':'Gray', '#B87333':'Yellow', '#F6DBD0':'Yellow', '#98925E':'Yellow', '#B59C5A;':'Yellow',
          '#FFFFFF':'White', '#C0C0C0':'Gray', 'goldenrod;':'Yellow', '#FEFEFE;':'White', 'gold':'Yellow',
          '#112959':'Green/Blue', '#073835': 'Green/Blue', '#1A3F73':'Green/Blue', '#FFFC00':'Yellow', '#FE0100':'Red',
          '#CC0000':'Red', '#B87333;':'Yellow', '62749A;':'Green/Blue', '#A7A0AB':'Gray', 'blank':'Unknown/Other',
          'black':'Black', '#62749A;':'Green/Blue',}

# %%
groups = []
for i in colors:
    try:
        group = color_groups[i]
        groups.append(group)
    except:
        print(i)

# %%
Counter(groups).most_common()
# Out:
# [('Yellow', 88),
#  ('Red', 63),
#  ('Unknown/Other', 29),
#  ('Green/Blue', 23),
#  ('White', 9),
#  ('Gray', 9),
#  ('Black', 5)]

# %%
import pandas as pd
cols = ['stardate', 'color', 'name', 'species', 'position', 'rank', 'designation', 'description', 'source']
df = pd.DataFrame.from_records(results, columns=cols)
df['color_group'] = groups
df
# Out:
#         stardate          color                   name              species  \
# 0           2153        #5B1414                 Fuller                Human
# 1           2153  Unknown/Other                    Sim      Mimetic simbiot
# 2           2153        #5B1414                Unnamed                Human
# 3           2153        #5B1414                Unnamed                Human
# 4           2153        #073835                Unnamed                Human
# 5    2153 | 2154    transparent  O'Malley, Patricia F.                Human
# 6           2154        #5B1414                Burrows                Human
# 7           2154    transparent                 Kamata                Human
# 8           2154    transparent                 Marcel                Human
# 9           2154        #5B1414           Taylor, Jane                Human
# 10          2154        #5B1414                Unnamed                Human
# 11          2154        #5B1414                Unnamed                Human
# 12          2155        #5B1414                 Masaro                Human
# 13          2161        #5B1414    Tucker III, Charles                Human
# 14          2153        #AD722C         Robinson, A.G.                Human
# 15          2154        #5B1414                Askwith                Human
# 16          2154        #FFFFFF       Forrest, Maxwell                Human
# 17          2164  Unknown/Other       Cormier, Randall                Human
# 18          2164        #1A3F73            Crosby, Mae                Human
# 19          2164        #742222          Noble, Meghan                Human
# 20          2164        #742222         Peters, Britni                Human
# 21          2164        #742222           Smith, Craig                Human
# 22          2164        #742222        Yanovich, Laura                Human
# 23          2167  Unknown/Other          Kelly, Morgan                Human
# 24          2167  Unknown/Other         Mullen, Steven                Human
# 25          2167  Unknown/Other          Shumar, Bryce                Human
# 26          2256        #B87333              Ash Tyler                Human
# 27          2256        #B87333                 Kowski                Human
# 28          2256        #B87333          Landry, Ellen                Human
# 29          2257        #C0C0C0            Hugh Culber                Human
# ..           ...            ...                    ...                  ...
# 196         2373        #AD722C                 Martin                Human
# 197         2373        #AD722C                  Seska           Cardassian
# 198         2373        #AD722C             Suder, Lon             Betazoid
# 199         2373        #143F48           Unidentified                Human
# 200         2373        #AD722C           Unidentified                Human
# 201         2374        #AD722C       Ballard, Lyndsay                Human
# 202         2374        #AD722C           Unidentified                Human
# 203         2374        #AD722C           Unidentified                Human
# 204         2378        #AD722C             Carey, Joe                Human
# 205         2374        #AD722C                Unnamed                Human
# 206         2374        #AD722C                Unnamed                Human
# 207         2376    transparent         Amantes, David
# 208         2376    transparent         Chang, Dorothy
# 209         2376    transparent           Bowler, John
# 210         2376    transparent         Yates, William
# 211         2376    transparent          Regis, Edward
# 212         2376        #8C212B         Burke, Maxwell                Human
# 213         2376        #8C212B        Ransom, Rudolph                Human
# 214         2376        #143F48               Thompson                Human
# 215         2354        #FEFEFE          Crusher, Jack                Human
# 216         2357        #FEFEFE          Rossa, Connor                Human
# 217         2364           gold          Jameson, Mark                Human
# 218         2364        #8C212B             Rice, Paul                Human
# 219         2368          black         Albert, Joshua                Human
# 220         2371        #FEFEFE   Kirk, James Tiberius                Human
# 221         2387    transparent                  Spock  Human/Vulcan hybrid
# 222         2374  Unknown/Other               Emmanuel                Human
# 223         2374        #8C212B              Strickler                Human
# 224         2374        #143F48           Unidentified                Human
# 225         2374        #5B1414       Janeway, Kathryn                Human
#
#                                position                  rank  \
# 0                      Tactical officer               Crewman
# 1                                               Other/No Rank
# 2                                                     Crewman
# 3                                                     Crewman
# 4                                                     Crewman
# 5                                                      Ensign
# 6                        Armory officer                Ensign
# 7                                                     Crewman
# 8                                                      Ensign
# 9                EPS control specialist            Lieutenant
# 10                             Engineer               Crewman
# 11                             Engineer               Crewman
# 12                             Engineer                Ensign
# 13                       Chief engineer             Commander
# 14                                              Other/No Rank
# 15   Security guardUnited Earth Embassy              Corporal
# 16                            Admiralty          Vice Admiral
# 17                                              Other/No Rank
# 18                                               Unknown Rank
# 19                                               Unknown Rank
# 20                                               Unknown Rank
# 21                                               Unknown Rank
# 22                                               Unknown Rank
# 23                           Lieutenant            Lieutenant
# 24                            Commander             Commander
# 25                              Captain         Other/No Rank
# 26                   Operations Officer            Lieutenant
# 27                     Security officer          Unknown rank
# 28                    Chief of security             Commander
# 29                            Physician  Lieutenant Commander
# ..                                  ...                   ...
# 196                Transporter operator                Ensign
# 197                             Crewman                Ensign
# 198                             Crewman              Enlisted
# 199                             Crewman          Unknown Rank
# 200                             Crewman          Unknown Rank
# 201                            Engineer                Ensign
# 202                                                   Crewman
# 203                                                    Ensign
# 204            Assistant Chief Engineer            Lieutenant
# 205                                       Chief petty officer
# 206                                                   Officer
# 207                                                   Crewman
# 208                                                    Ensign
# 209                                                Lieutenant
# 210                                                Lieutenant
# 211                                                    Ensign
# 212                                  XO            Lieutenant
# 213                  Commanding officer               Captain
# 214                                                   Crewman
# 215                       USS Stargazer  Lieutenant Commander
# 216                            Galen IV  Lieutenant Commander
# 217          AdmiraltyStarfleet Command          Rear Admiral
# 218                  Commanding Officer               Captain
# 219      Nova SquadronStarfleet Academy                 Cadet
# 220                  Inactive (retired)               Captain
# 221        Commanding officer,Jellyfish            Ambassador
# 222                                              Unknown Rank
# 223                                                    Ensign
# 224                      Bridge officer          Unknown Rank
# 225      Commanding officer,USS Voyager               Captain
#
#               designation                                        description  \
# 0    Other/No Designation                         Killed by Osaarian pirates
# 1    Other/No Designation  Created to provide Charles Tucker III with vit...
# 2    Other/No Designation                         Shot by a Xindi bio weapon
# 3    Other/No Designation                         Shot by a Xindi bio weapon
# 4    Other/No Designation  Killed by a Triannon organic explosive and the...
# 5    Other/No Designation          Died "in a battle with a hostile species"
# 224  Other/No Designation  Killed during an attack of a Krenim warship, d...
# 225  Other/No Designation  Died in the explosion when she set a collision...
#
#                                                 source    color_group
# 0                                       ENT: "Anomaly"            Red
# 1                                    ENT: "Similitude"  Unknown/Other
# 2                                        ENT: "Rajiin"            Red
# 3                                        ENT: "Rajiin"            Red
# 4                                  ENT: "Chosen Realm"     Green/Blue
# 5                          ENT: "Storm Front, Part II"  Unknown/Other
# 6                                      ENT: "Daedalus"            Red
# 7                                 ENT: "The Forgotten"  Unknown/Other
# 8                                 ENT: "The Forgotten"  Unknown/Other
# 9                                 ENT: "The Forgotten"            Red
# 10                                  ENT: "Azati Prime"            Red
# 11                                    ENT: "Zero Hour"            Red
# 12                                  ENT: "Terra Prime"            Red
# 13                     ENT: "These Are the Voyages..."            Red
# 14                                 ENT: "First Flight"         Yellow
# 15                                    ENT: "The Forge"            Red
# 16                                    ENT: "The Forge"          White
# 17                                    Star Trek Beyond  Unknown/Other
# 18                                    Star Trek Beyond     Green/Blue
# 19                                    Star Trek Beyond            Red
# 20                                    Star Trek Beyond            Red
# 21                                    Star Trek Beyond            Red
# 22                                    Star Trek Beyond            Red
# 23                                   TNG: "Power Play"  Unknown/Other
# 24                                   TNG: "Power Play"  Unknown/Other
# 25                                   TNG: "Power Play"  Unknown/Other
# 26                            DIS: "Vaulting Ambition"         Yellow
# 27                         DIS: "Context Is for Kings"         Yellow
# 28   DIS: "The Butcher's Knife Cares Not for the La...         Yellow
# 29   DIS: "Despite Yourself", reversed in DIS: "Sai...           Gray
# ..                                                 ...            ...
# 196                                     VOY: "Warlord"         Yellow
# 197                             VOY: "Basics, Part II"         Yellow
# 198                             VOY: "Basics, Part II"         Yellow
# 199                             VOY: "Basics, Part II"     Green/Blue
# 200                                   VOY: "The Swarm"         Yellow
# 201                              VOY: "Ashes to Ashes"         Yellow
# 202                           VOY: "Scientific Method"         Yellow
# 203                                         VOY: "One"         Yellow
# 204                              VOY: "Friendship One"         Yellow
# 205                         VOY: "Message in a Bottle"         Yellow
# 206                         VOY: "Message in a Bottle"         Yellow
# 207                                     VOY: "Equinox"  Unknown/Other
# 208                                     VOY: "Equinox"  Unknown/Other
# 209                                     VOY: "Equinox"  Unknown/Other
# 210                                     VOY: "Equinox"  Unknown/Other
# 211                                     VOY: "Equinox"  Unknown/Other
# 212                            VOY: "Equinox, Part II"            Red
# 213                            VOY: "Equinox, Part II"            Red
# 214                            VOY: "Equinox, Part II"     Green/Blue
# 215                       TNG: "Encounter at Farpoint"          White
# 216                              TNG: "Suddenly Human"          White
# 217                          TNG: "Too Short a Season"         Yellow
# 218                      TNG: "The Arsenal of Freedom"            Red
# 219                              TNG: "The First Duty"          Black
# 220                              Star Trek Generations          White
# 221                                          Star Trek  Unknown/Other
# 222                                VOY: "Year of Hell"  Unknown/Other
# 223                                VOY: "Year of Hell"            Red
# 224                                VOY: "Year of Hell"     Green/Blue
# 225                       VOY: "Year of Hell, Part II"            Red
#
# [226 rows x 10 columns]

# %%
df.to_csv("uncorrected_death_scrape.csv")
